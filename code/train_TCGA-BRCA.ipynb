# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import warnings
warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
path_蛋白质组 = ''  
path_dna甲基化 = ''
path_转录组 = ''
path_拷贝数变化 = ''
path_临床数据 = ''

# %%
df_蛋白质组 = pd.read_csv(path_蛋白质组)
# df_蛋白质组 = df_蛋白质组.drop(['Unnamed: 0'],axis=1)
df_dna甲基化 = pd.read_csv(path_dna甲基化)
df_转录组 = pd.read_csv(path_转录组)
df_拷贝数变化 = pd.read_csv(path_拷贝数变化)
df_临床 = pd.read_csv(path_临床数据)

df_dna甲基化 = df_dna甲基化.iloc[:,1:27]
df_拷贝数变化 = df_拷贝数变化.iloc[:,1:118]
df_蛋白质组 = df_蛋白质组.iloc[:,1:464]
df_转录组 = df_转录组.iloc[:,1:589]

# %%
x = df_临床.iloc[:,1:23]
y = df_临床.iloc[:,23:]

# %%
y = y.replace({'WITH TUMOR': 1, 'TUMOR FREE': 0})

# %%
y.value_counts()
# Out:
# cancer_status
# 0                204
# 1                104
# dtype: int64

# %%
# 找出x中类型为object的列
tmp = x[x.columns[x.dtypes == 'object']]

from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

labelEncoder_dict = {}

# 对多个列进行编码
for col in tmp.columns:
    le = LabelEncoder()
    tmp[col] = le.fit_transform(tmp[col])
    labelEncoder_dict[col] = le
tmp.head()
x[x.columns[x.dtypes == 'object']] = tmp
df_临床 = x

# %%
print(df_dna甲基化.shape,df_拷贝数变化.shape,df_蛋白质组.shape,df_转录组.shape,df_临床.shape)
print(df_dna甲基化.shape[1]+df_拷贝数变化.shape[1]+df_蛋白质组.shape[1]+df_转录组.shape[1]+df_临床.shape[1])
# Out:
# (308, 26) (308, 117) (308, 463) (308, 588) (308, 22)
# 1216

# %%
# 假设每个组学的数据存储在字典中，键为组学名，值为DataFrame
omics_data = {
    'dna甲基化': df_dna甲基化,
    '拷贝数变化': df_拷贝数变化,
    '蛋白质组': df_蛋白质组,
    '转录组': df_转录组,
    '临床': df_临床
}

# 处理每个组学数据，填充缺失值,不填充缺失值无法画图
omics_data_knn = {}
for name, df in omics_data.items():
    cols = df.columns
    # 填充缺失值
    imputer = KNNImputer(n_neighbors=10)
    df = imputer.fit_transform(df)
    df = pd.DataFrame(df,columns=cols)

    omics_data_knn[name] = df

# %%
# 处理每个组学数据，标准化
processed_omics = {}
for name, df in omics_data_knn.items():
    # 标准化
    scaler = StandardScaler()
    scaled_df = scaler.fit_transform(df)

    processed_omics[name] = scaled_df

# %%
import torch
import torch.nn as nn
import random

# 设置全局随机种子
seed = 43

# Python & NumPy
random.seed(seed)    # Python内置random模块
np.random.seed(seed) # NumPy随机数生成器

# PyTorch的随机种子设置（同时适用于CPU和GPU）
torch.manual_seed(seed)       # CPU随机种子

# %%
# 获取每个组学的特征数
feature_dims = [df_dna甲基化.shape[1], df_拷贝数变化.shape[1], df_蛋白质组.shape[1], df_转录组.shape[1], df_临床.shape[1]]

# 将数据拼接为 (308, 5, 最大特征数)
max_features = max(feature_dims)
data = np.zeros((308, 5, max_features))  # 初始化数组

# 填充数据
data[:, 0, :feature_dims[0]] = processed_omics['dna甲基化']
data[:, 1, :feature_dims[1]] = processed_omics['拷贝数变化']
data[:, 2, :feature_dims[2]] = processed_omics['蛋白质组']
data[:, 3, :feature_dims[3]] = processed_omics['转录组']
data[:, 4, :feature_dims[4]] = processed_omics['临床']
# 填充后的数据就是 308 5 最大特征数 (26, 146, 461, 581, 22) 5各组学的特征数，没有数据的部分补充为0
# 这样数据为0的部分就可以忽略不计，算法也可以处理，这样都不需要降维

# %%
data[:,0,:feature_dims[0]].shape  # 第一个组学数据的特征维度
# Out:
# (308, 26)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y.to_numpy().flatten(), test_size=0.2, random_state=seed)

# %%
X_train[:,0,:feature_dims[0]].shape
# Out:
# (246, 26)

# %%
# 转换为 PyTorch 张量
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)

y_train = torch.tensor(y_train, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
from torch.utils.data import DataLoader, TensorDataset

# 创建数据集
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
from multi_omics_net_ import MultiOmicsNet
from multi_omics_net import huatu
from multi_omics_net import display_performance

# %%
def train(train_loader, X_test, y_test):

    # 初始化模型
    model = MultiOmicsNet(
    n_omics=5,
    d_model=128, #128 64  Transformer编码器输入输出维度
    nhead=4,
    dim_feedforward=256, #512
    dropout=0.5,
    input_dims=[feature_dims[0],feature_dims[1],feature_dims[2],feature_dims[3],feature_dims[4]]
    )   # 各组的原始特征维度


    # 训练配置
    criterion = nn.BCEWithLogitsLoss()
    

    # 获取除最后一层外的所有参数
    base_params = [param for name, param in model.named_parameters() 
                  if not name.startswith("logits_predictor.")]
    # 训练配置，最后一层使用10倍学习率
    optimizer = torch.optim.Adam([
        {'params': base_params},
        {'params': model.logits_predictor.parameters(), 'lr': 1e-3}  # 最后一层使用10倍学习率
    ], lr=1e-4,)  # 基础学习率

    # optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    # 学习率调度器，使用余弦衰减学习率,T_max=100
    # 如果验证集性能在某个epoch后不再提升，可以将T_max设置为该epoch数，以加速收敛。
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)


    train_losses = []
    test_losses = []
    test_accuracies = []
    test_aucs = []

    import copy
    best_epoch = 0
    max_auc = 0
    best_model = None

    # 训练循环
    for epoch in range(30): 
        model.train()
        train_loss = 0
        for x, y in train_loader: #每个batch 32 个样本
            optimizer.zero_grad()
            pred = model(
                [
                x[:, 0, :feature_dims[0]],
                x[:, 1, :feature_dims[1]],
                x[:, 2, :feature_dims[2]],
                x[:, 3, :feature_dims[3]],
                x[:, 4, :feature_dims[4]]
                ]
            )[0].squeeze()

            loss = criterion(pred, y) # BCEWithLogitsLoss 结合了 sigmoid 和 BCELoss
            train_loss += loss.item() # 累记训练损失
            loss.backward()  # 反向传播
            optimizer.step() # 更新网络中的参数
            # scheduler.step()  # 更新学习率
        
        train_losses.append(train_loss)

        # 评估
        test_loss = 0
        test_accuracy = 0
        test_auc = 0
        model.eval()
        with torch.no_grad():
            # 计算测试损失
            pred_probability,attn_weights_list_all_omics,encoded_features,features = model(
                [
                X_test[:, 0, :feature_dims[0]],
                X_test[:, 1, :feature_dims[1]],
                X_test[:, 2, :feature_dims[2]],
                X_test[:, 3, :feature_dims[3]],
                X_test[:, 4, :feature_dims[4]]
                ]
            )

            test_loss = criterion(pred_probability.squeeze(), y_test)
            test_losses.append(test_loss.item())

            # 此处使用sigmoid函数 将 输出转换为概率，方便计算AUC，准确率
            y_pred = torch.sigmoid(pred_probability).detach().numpy()
            y_pred = (y_pred > 0.5).astype(int)

            # 计算测试准确率
            test_accuracy = accuracy_score(y_test.numpy(), y_pred)
            test_accuracies.append(test_accuracy)

            # 计算AUC
            test_auc = roc_auc_score(y_test.numpy(), y_pred)
            test_aucs.append(test_auc)

            # 保存最佳模型
            if test_auc > max_auc:
                if test_loss < train_loss: #未过拟合
                    best_epoch = epoch + 1
                    max_auc = test_auc
                    best_model = copy.deepcopy(model)

        print(f"Epoch {epoch+1},Train Loss: {train_loss:.4f},Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Test AUC: {test_auc:.4f}")

    print(f"Best Epoch: {best_epoch}, Best AUC: {max_auc:.4f}") 

    return best_model, train_losses, test_losses, test_accuracies, test_aucs

# %%
# del best_model
best_model,train_losses,test_losses,test_accuracies,test_aucs = train(train_loader,X_test,y_test)
huatu(train_losses,test_losses,test_accuracies,test_aucs)
display_performance(best_model,X_test,y_test,feature_dims)  # 单次运行，结果受1.数据的分布 ; 2.模型参数默认初始化的影响

# Accuracy: 0.94
# AUC: 0.97
# 敏感性: 0.92
# 特异性: 0.95
# PPV: 0.92
# NPV: 0.95
# Out:
# Epoch 1,Train Loss: 5.0963,Test Loss: 0.7414, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 2,Train Loss: 5.0498,Test Loss: 0.6908, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 3,Train Loss: 5.0159,Test Loss: 0.6913, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 4,Train Loss: 5.0414,Test Loss: 0.7237, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 5,Train Loss: 5.0402,Test Loss: 0.6935, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 6,Train Loss: 5.0025,Test Loss: 0.6761, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 7,Train Loss: 4.9930,Test Loss: 0.7015, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 8,Train Loss: 4.9858,Test Loss: 0.7067, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 9,Train Loss: 5.0174,Test Loss: 0.6918, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 10,Train Loss: 4.9946,Test Loss: 0.6799, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 11,Train Loss: 4.9835,Test Loss: 0.6835, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 12,Train Loss: 4.9788,Test Loss: 0.6977, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 13,Train Loss: 4.9268,Test Loss: 0.6616, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 14,Train Loss: 4.9192,Test Loss: 0.6908, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 15,Train Loss: 4.7783,Test Loss: 0.6307, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 16,Train Loss: 4.6336,Test Loss: 0.7169, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 17,Train Loss: 4.6311,Test Loss: 0.5838, Test Accuracy: 0.6452, Test AUC: 0.5600
# Epoch 18,Train Loss: 4.2188,Test Loss: 0.6495, Test Accuracy: 0.5968, Test AUC: 0.5000
# Epoch 19,Train Loss: 3.7818,Test Loss: 0.5411, Test Accuracy: 0.6613, Test AUC: 0.5800
# Epoch 20,Train Loss: 3.0772,Test Loss: 0.4371, Test Accuracy: 0.7903, Test AUC: 0.7530
# Epoch 21,Train Loss: 2.5757,Test Loss: 0.4085, Test Accuracy: 0.8226, Test AUC: 0.7930
# Epoch 22,Train Loss: 2.0902,Test Loss: 0.3691, Test Accuracy: 0.8710, Test AUC: 0.8530
# Epoch 23,Train Loss: 1.8229,Test Loss: 0.4315, Test Accuracy: 0.8387, Test AUC: 0.8065
# Epoch 24,Train Loss: 1.5490,Test Loss: 0.3456, Test Accuracy: 0.9032, Test AUC: 0.8930
# Epoch 25,Train Loss: 1.4162,Test Loss: 0.3317, Test Accuracy: 0.9194, Test AUC: 0.9130
# Epoch 26,Train Loss: 1.2505,Test Loss: 0.3053, Test Accuracy: 0.9355, Test AUC: 0.9330
# Epoch 27,Train Loss: 1.1452,Test Loss: 0.4108, Test Accuracy: 0.8871, Test AUC: 0.8600
# Epoch 28,Train Loss: 1.0089,Test Loss: 0.3063, Test Accuracy: 0.9355, Test AUC: 0.9330
# Epoch 29,Train Loss: 0.8427,Test Loss: 0.4305, Test Accuracy: 0.8710, Test AUC: 0.8400
# Epoch 30,Train Loss: 0.7015,Test Loss: 0.3580, Test Accuracy: 0.8710, Test AUC: 0.8530
# Best Epoch: 26, Best AUC: 0.9330
# Accuracy: 0.94
# AUC: 0.97
# 敏感性: 0.92
# 特异性: 0.95
# PPV: 0.92
# NPV: 0.95

# %%
# 保存best_model
# torch.save(best_model.state_dict(), 'model_weights.pth') # 保存模型参数
# torch.save(best_model, 'MultiOmicsNet.pth') # 保存整个模型

# %%
# 使用10折交叉验证，评价模型性能
from sklearn.model_selection import KFold
import pickle
import joblib

# 固定随机种子保证数据划分可复现
kf = KFold(n_splits=10, shuffle=True, random_state=43)

omics_contributions_list = []  #存储每折中 每个样本的每个omic的注意力权重
test_index_list = []  # 存储每折中，每个测试集的索引

y_test_list = []  #存储每折中 用于测试样本的真实标签
preds_list = []  #存储每折中 用于测试样本的预测标签
preds_proba_list = []  #存储每折中 用于测试样本的预测概率

omics_shap_values_all = []  #存储每折中 每个样本的每个omic的shap值累加和

encoded_features_list = [] # 模型训练好后，单个组学被编码器捕获的特征
features_list = []  # 模型训练好后，融合被捕获的特征再被编码器捕获的特征


for fold, (train_idx, test_idx) in enumerate(kf.split(data)):
    print(f"\n=== Fold {fold+1}/10 ===")

    tmp_y = y.to_numpy().flatten()

    # 划分训练集和验证集
    X_train, X_test = data[train_idx], data[test_idx]
    y_train, y_test = tmp_y[train_idx], tmp_y[test_idx]

    # 转换为 PyTorch 张量
    X_train = torch.tensor(X_train, dtype=torch.float32)
    X_test = torch.tensor(X_test, dtype=torch.float32)

    y_train = torch.tensor(y_train, dtype=torch.float32)
    y_test = torch.tensor(y_test, dtype=torch.float32)

    # 创建数据集
    train_dataset = TensorDataset(X_train, y_train)
    test_dataset = TensorDataset(X_test, y_test)

    # 创建数据加载器
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)


    best_model,train_losses,test_losses,test_accuracies,test_aucs = train(train_loader,X_test,y_test)
    # 保存模型
    joblib.dump(best_model, './saved_model/MoN-F-TCGA/MoN_'+str(fold+1)+'.pkl')

    best_model.eval()
    with torch.no_grad():
        # 计算测试损失
        pred_probability,attn_weights_list_all_omics, encoded_features, features = best_model(
            [
                X_test[:, 0, :feature_dims[0]],
                X_test[:, 1, :feature_dims[1]],
                X_test[:, 2, :feature_dims[2]],
                X_test[:, 3, :feature_dims[3]],
                X_test[:, 4, :feature_dims[4]]
            ]
        )
        
        # 此处使用sigmoid函数 将 输出转换为概率，方便计算AUC，准确率
        y_pred_proba = torch.sigmoid(pred_probability).detach().numpy()
        y_pred = (y_pred_proba > 0.5).astype(int).flatten()


        y_test_list = y_test_list + list(tmp_y[test_idx])  #存储每折中 用于测试样本的真实标签
        preds_list =  preds_list + list(y_pred) #存储每折中 用于测试样本的预测标签
        preds_proba_list =  preds_proba_list + list(y_pred_proba.flatten()) #存储每折中 用于测试样本的预测概率

        encoded_features_list.append(encoded_features) # 模型训练好后，单个组学被编码器捕获的特征
        features_list.append(features)  # 模型训练好后，融合被捕获的特征再被编码器捕获的特征

        combined_attn = torch.stack(attn_weights_list_all_omics)
        omics_contributions_list.append(combined_attn) #存储每折中 每个样本的每个omic的注意力权重
    
    test_index_list += list(test_idx)

    # 计算这一折的SHAP值
    omics_shap_values = calculate_shap_values(best_model,X_train,X_test,feature_dims)
    omics_shap_values_all.append(omics_shap_values)
# Out:
# === Fold 1/10 ===
# Epoch 1,Train Loss: 5.7867,Test Loss: 0.7187, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 2,Train Loss: 5.7602,Test Loss: 0.7088, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 3,Train Loss: 5.7283,Test Loss: 0.7005, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 4,Train Loss: 5.6688,Test Loss: 0.6906, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 5,Train Loss: 5.7783,Test Loss: 0.7126, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 6,Train Loss: 5.6324,Test Loss: 0.6863, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 7,Train Loss: 5.6180,Test Loss: 0.7048, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 8,Train Loss: 5.6700,Test Loss: 0.7190, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 9,Train Loss: 5.6388,Test Loss: 0.6803, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 10,Train Loss: 5.6479,Test Loss: 0.7027, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 11,Train Loss: 5.5674,Test Loss: 0.6960, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 12,Train Loss: 5.6097,Test Loss: 0.6889, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 13,Train Loss: 5.4305,Test Loss: 0.6549, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 14,Train Loss: 5.3038,Test Loss: 0.6197, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 15,Train Loss: 5.0554,Test Loss: 0.6925, Test Accuracy: 0.5806, Test AUC: 0.5000
# Epoch 16,Train Loss: 4.5099,Test Loss: 0.5309, Test Accuracy: 0.8387, Test AUC: 0.8397
# Epoch 17,Train Loss: 4.2925,Test Loss: 0.5274, Test Accuracy: 0.6129, Test AUC: 0.5491
# Epoch 18,Train Loss: 3.4312,Test Loss: 0.5423, Test Accuracy: 0.7419, Test AUC: 0.6923
# Epoch 19,Train Loss: 2.8186,Test Loss: 0.3590, Test Accuracy: 0.8710, Test AUC: 0.8675
# Epoch 20,Train Loss: 2.1202,Test Loss: 0.3313, Test Accuracy: 0.8710, Test AUC: 0.8675
# Epoch 21,Train Loss: 1.7525,Test Loss: 0.3851, Test Accuracy: 0.9032, Test AUC: 0.8953
# Epoch 22,Train Loss: 1.2815,Test Loss: 0.2951, Test Accuracy: 0.9032, Test AUC: 0.8953
Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 16,Train Loss: 5.3098,Test Loss: 0.6299, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 17,Train Loss: 5.0041,Test Loss: 0.5615, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 18,Train Loss: 4.5454,Test Loss: 0.5000, Test Accuracy: 0.9677, Test AUC: 0.9737
# Epoch 19,Train Loss: 4.1928,Test Loss: 0.3612, Test Accuracy: 0.9032, Test AUC: 0.8750
# Epoch 20,Train Loss: 3.1335,Test Loss: 0.2973, Test Accuracy: 0.9032, Test AUC: 0.8750
# Epoch 21,Train Loss: 2.3230,Test Loss: 0.4281, Test Accuracy: 0.7742, Test AUC: 0.7083
# Epoch 22,Train Loss: 2.0391,Test Loss: 0.1622, Test Accuracy: 1.0000, Test AUC: 1.0000
# Epoch 23,Train Loss: 1.6009,Test Loss: 0.1766, Test Accuracy: 0.9677, Test AUC: 0.9583
# Epoch 24,Train Loss: 1.1724,Test Loss: 0.1337, Test Accuracy: 0.9677, Test AUC: 0.9583
# Epoch 25,Train Loss: 1.0011,Test Loss: 0.1478, Test Accuracy: 0.9677, Test AUC: 0.9583
# Epoch 26,Train Loss: 0.7717,Test Loss: 0.0904, Test Accuracy: 0.9677, Test AUC: 0.9583
# Epoch 27,Train Loss: 0.6540,Test Loss: 0.1131, Test Accuracy: 0.9355, Test AUC: 0.9167
# Epoch 28,Train Loss: 0.4544,Test Loss: 0.0449, Test Accuracy: 1.0000, Test AUC: 1.0000
# Epoch 29,Train Loss: 0.4287,Test Loss: 0.1383, Test Accuracy: 0.9355, Test AUC: 0.9167
# Epoch 30,Train Loss: 0.5253,Test Loss: 0.1255, Test Accuracy: 0.9677, Test AUC: 0.9583
# Best Epoch: 22, Best AUC: 1.0000
#
# === Fold 7/10 ===
# Epoch 1,Train Loss: 5.9293,Test Loss: 0.6706, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 2,Train Loss: 5.7503,Test Loss: 0.6837, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 3,Train Loss: 5.7243,Test Loss: 0.6821, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 4,Train Loss: 5.7278,Test Loss: 0.6740, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 5,Train Loss: 5.8556,Test Loss: 0.6814, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 6,Train Loss: 5.7791,Test Loss: 0.6948, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 7,Train Loss: 5.6936,Test Loss: 0.6673, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 8,Train Loss: 5.6966,Test Loss: 0.6706, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 9,Train Loss: 5.6984,Test Loss: 0.6844, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 10,Train Loss: 5.6797,Test Loss: 0.6713, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 11,Train Loss: 5.6910,Test Loss: 0.6629, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 12,Train Loss: 5.5984,Test Loss: 0.6731, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 13,Train Loss: 5.6182,Test Loss: 0.6725, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 14,Train Loss: 5.5357,Test Loss: 0.6320, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 15,Train Loss: 5.5211,Test Loss: 0.6422, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 16,Train Loss: 5.1937,Test Loss: 0.5975, Test Accuracy: 0.6129, Test AUC: 0.5000
# Epoch 17,Train Loss: 4.8702,Test Loss: 0.5456, Test Accuracy: 0.6774, Test AUC: 0.5833
# Epoch 18,Train Loss: 4.3090,Test Loss: 0.4873, Test Accuracy: 0.8065, Test AUC: 0.7500
# Epoch 19,Train Loss: 3.5691,Test Loss: 0.4492, Test Accuracy: 0.8387, Test AUC: 0.8224
# Epoch 20,Train Loss: 3.0433,Test Loss: 0.4318, Test Accuracy: 0.8065, Test AUC: 0.7961
# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,confusion_matrix

# 计算置信区间
def bootstrap_ci(y_true, y_pred, y_score=None, n_boot=2000, seed=42):
    rng = np.random.RandomState(seed)
    metrics = ["AUC","ACC","SENS","SPEC","PPV","NPV","F1"]
    results = {m: [] for m in metrics}

    for _ in range(n_boot):
        idx = rng.randint(0, len(y_true), len(y_true)) #随机抽取样本计算
        y_t = y_true[idx]
        y_p = y_pred[idx]
        y_s = y_score[idx] if y_score is not None else None

        
        # 反复抽样太多次，出现只有一个类别时，计算指标会报错
        # 检查是否只有一个类别
        unique_classes = np.unique(y_t)
        if len(unique_classes) == 1:
            # 只有一个类别时，所有指标设为NaN
            results["ACC"].append(np.nan)
            results["SENS"].append(np.nan)
            results["SPEC"].append(np.nan)
            results["PPV"].append(np.nan)
            results["NPV"].append(np.nan)
            results["F1"].append(np.nan)
        else:
            # 正常计算混淆矩阵
            tn, fp, fn, tp = confusion_matrix(y_t, y_p).ravel()
            results["ACC"].append((tp + tn) / (tp + tn + fp + fn))
            results["SENS"].append(tp / (tp + fn) if (tp + fn) > 0 else np.nan)
            results["SPEC"].append(tn / (tn + fp) if (tn + fp) > 0 else np.nan)
            results["PPV"].append(tp / (tp + fp) if (tp + fp) > 0 else np.nan)
            results["NPV"].append(tn / (tn + fn) if (tn + fn) > 0 else np.nan)
            results["F1"].append(f1_score(y_t, y_p))

        if y_s is not None:
            # results["AUC"].append(roc_auc_score(y_t, y_s))
            try:
                # 随机抽取的样本，可能只有一个类别，导致计算错误，检查是否只有一个类别
                if len(np.unique(y_t)) == 1:
                    results["AUC"].append(np.nan)
                else:
                    results["AUC"].append(roc_auc_score(y_t, y_s))
            except ValueError:
                # 处理roc_auc_score可能抛出的其他错误
                results["AUC"].append(np.nan)
        else:
            results["AUC"].append(np.nan)

    ci = {}
    for m in metrics:
        arr = np.array(results[m])
        ci[m] = {
            "mean": np.nanmean(arr),
            "low": np.nanpercentile(arr, 2.5),
            "high": np.nanpercentile(arr, 97.5)
        }

    return ci

# 计算性能
def calculate_metrics(y_true, y_scores, threshold=0.5):
    """
    计算二分类模型的评估指标
    
    Parameters:
    y_true: 真实标签 (0或1)
    y_scores: 预测概率或分数
    threshold: 分类阈值，默认为0.5
    
    Returns:
    dict: 包含所有评估指标的字典
    """
    # y_true = eval(y_true)
    # y_scores = eval(y_scores)
    # 转换为numpy数组确保正确处理
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    # 将概率转换为预测标签
    y_pred = (y_scores >= threshold).astype(int)
    # 计算混淆矩阵
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # 计算各个指标
    # 使用预测标签计算的AUC值可能不准确，这会导致模型性能评估出现偏差
    auc = round(roc_auc_score(y_true, y_scores),3) 
    acc = round(accuracy_score(y_true, y_pred),3)
    sens = round(recall_score(y_true, y_pred),3)  # 敏感性 = 召回率
    spec = round(tn / (tn + fp),3)  # 特异性
    ppv = round(precision_score(y_true, y_pred),3)  # 阳性预测值 = 精确率
    npv = round(tn / (tn + fn),3)  # 阴性预测值
    f1 = round(f1_score(y_true, y_pred),3)

    ci = bootstrap_ci(y_true, y_pred, y_scores, n_boot=1000, seed=42) # n_boot 超过1000以上
    
    # 处理NaN值的情况
    if np.isnan(auc):
        auc_ci = "(N/A)"
        # auc = "N/A"
    else:
        auc_ci = f"({ci['AUC']['low']:.3f}–{ci['AUC']['high']:.3f})"
        # auc = f"{auc:.3f}"

    # auc_ci = f"({ci['AUC']['low']:.3f}–{ci['AUC']['high']:.3f})"
    acc_ci = f"({ci['ACC']['low']:.3f}–{ci['ACC']['high']:.3f})"
    sens_ci = f"({ci['SENS']['low']:.3f}–{ci['SENS']['high']:.3f})"
    spec_ci = f"({ci['SPEC']['low']:.3f}–{ci['SPEC']['high']:.3f})"
    ppv_ci = f"({ci['PPV']['low']:.3f}–{ci['PPV']['high']:.3f})"
    npv_ci = f"({ci['NPV']['low']:.3f}–{ci['NPV']['high']:.3f})"
    f1_ci = f"({ci['F1']['low']:.3f}–{ci['F1']['high']:.3f})"
    

    AUC = f"{auc:.3f}"+auc_ci
    ACC = f"{acc:.3f}"+acc_ci
    SENS = f"{sens:.3f}"+sens_ci
    SPEC = f"{spec:.3f}"+spec_ci
    PPV = f"{ppv:.3f}"+ppv_ci
    NPV = f"{npv:.3f}"+npv_ci
    F1 = f"{f1:.3f}"+f1_ci

    # return auc,acc,sens,spec,ppv,npv,f1
    return AUC,ACC,SENS,SPEC,PPV,NPV,F1

# %%
calculate_metrics(y_test_list, preds_proba_list, threshold=0.5)
# AUC
# accuracy_score
# SENS
# SPEC
# PPV
# NPV
# F1

# ('0.927(0.889–0.962)',
#  '0.922(0.893–0.951)',
#  '0.923(0.869–0.971)',
#  '0.922(0.884–0.958)',
#  '0.857(0.792–0.920)',
#  '0.959(0.931–0.985)',
#  '0.889(0.844–0.932)')
# Out:
# ('0.927(0.889–0.962)',
#  '0.922(0.893–0.951)',
#  '0.923(0.869–0.971)',
#  '0.922(0.884–0.958)',
#  '0.857(0.792–0.920)',
#  '0.959(0.931–0.985)',
#  '0.889(0.844–0.932)')

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve, auc, average_precision_score

# 计算准确率
accuracy = accuracy_score(y_test_list, preds_list)
print(f"Accuracy: {accuracy:.2f}")
# 计算AUROC
auroc = roc_auc_score(y_test_list, preds_proba_list)
print(f"AUROC: {auroc:.2f}")
# 计算AUPRC
precision, recall, _ = precision_recall_curve(y_test_list, preds_proba_list)
auprc = auc(recall, precision)
print(f"AUPRC: {auprc:.2f}")
# 计算F1值
f1 = f1_score(y_test_list, preds_list)
print(f"F1 Score: {f1:.2f}")
# 计算混淆矩阵
tn, fp, fn, tp = confusion_matrix(y_test_list, preds_list).ravel()
# 计算敏感性（召回率）
sensitivity = tp / (tp + fn)
print(f"敏感性: {sensitivity:.2f}")
# 计算特异性
specificity = tn / (tn + fp)
print(f"特异性: {specificity:.2f}")
# 计算阳性预测值（PPV）
ppv = tp / (tp + fp)
print(f"PPV: {ppv:.2f}")
# 计算阴性预测值（NPV）
npv = tn / (tn + fn)
print(f"NPV: {npv:.2f}")

# Accuracy: 0.92
# AUROC: 0.93
# AUPRC: 0.84
# F1 Score: 0.89
# 敏感性: 0.92
# 特异性: 0.92
# PPV: 0.86
# NPV: 0.96
# Out:
# Accuracy: 0.92
# AUROC: 0.93
# AUPRC: 0.84
# F1 Score: 0.89
# 敏感性: 0.92
# 特异性: 0.92
# PPV: 0.86
# NPV: 0.96

# %%
len(test_index_list)
# len(y_test_list)
# len(preds_list)
# len(preds_proba_list)
# Out:
# 308
